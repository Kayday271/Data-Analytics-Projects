jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (331).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (223).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (223).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (389).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (389).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (366).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (366).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (311).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (311).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (254).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (254).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (92).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (92).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (487).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (487).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (192).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (192).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (468).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (468).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (346).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (346).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (203).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (203).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (350).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (350).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (215).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (215).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (429).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (429).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (307).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (307).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (242).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (242).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (491).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (491).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (84).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (84).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (184).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (184).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (239).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (239).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (393).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (393).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (10).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (10).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (405).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (405).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (540).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (540).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (110).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (110).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (281).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (281).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (452).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (452).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (47).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (47).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (147).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (147).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (517).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (517).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (278).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (278).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (297).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (297).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (51).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (51).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (444).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (444).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (501).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (501).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (151).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (151).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (385).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (385).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (413).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (413).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (106).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (106).jpg
#   inflating: The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (556).jpg
#   inflating: __MACOSX/The IQ-OTHNCCD lung cancer dataset/Malignant cases/._Malignant case (556).jpg

# %% [markdown]
# # Required imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.backend import tf as ktf
from keras.callbacks import TensorBoard
from datetime import datetime
# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# %%
import tensorboard
tensorboard.__version__
# Out:
# '2.8.0'

# %%
# Define the Keras TensorBoard callback.
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=logdir, histogram_freq=1)

# %% [markdown]
# # Multi classifier model implementation

# %% [markdown]
# ### Load images using an ImageDataGenerator. With this object we also apply augmentation

# %% [markdown]
# ### We will create two copies of the training and validation datasets. One will contain Data Augmentation while the others won't

# %%
datagen = ImageDataGenerator(validation_split=0.2)

datagen_ia = ImageDataGenerator(
    rescale = 1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip = True,
    fill_mode = 'nearest',
    validation_split=0.2)

train_generator = datagen.flow_from_directory('The IQ-OTHNCCD lung cancer dataset/',
                                              target_size = (300,300),
                                              class_mode = 'categorical',
                                              subset='training')

test_generator = datagen.flow_from_directory('The IQ-OTHNCCD lung cancer dataset/',
                                              target_size = (300,300),
                                              class_mode = 'categorical',
                                              subset='validation')

train_generator_ia = datagen_ia.flow_from_directory('The IQ-OTHNCCD lung cancer dataset/',
                                              target_size = (300,300),
                                              class_mode = 'categorical',
                                              subset='training')

test_generator_ia = datagen_ia.flow_from_directory('The IQ-OTHNCCD lung cancer dataset/',
                                              target_size = (300,300),
                                              class_mode = 'categorical',
                                              subset='validation')
# Out:
# Found 878 images belonging to 3 classes.
# Found 219 images belonging to 3 classes.
# Found 878 images belonging to 3 classes.
# Found 219 images belonging to 3 classes.

# %% [markdown]
# ### Base Model

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten()) # Flattens the input to 1D
model.add(tf.keras.layers.Dense(512, activation = 'relu'))
model.add(tf.keras.layers.Dense(1024, activation = 'relu'))
model.add(tf.keras.layers.Dense(3, activation = 'softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy', tf.keras.metrics.Recall()])

history1 = model.fit(
      train_generator,
      epochs=20,
      verbose=1,
      validation_data = test_generator)
# Out:
# Epoch 1/20
# 28/28 [==============================] - 33s 1s/step - loss: 14295.0576 - accuracy: 0.4727 - recall: 0.4727 - val_loss: 3454.9565 - val_accuracy: 0.5251 - val_recall: 0.5251
# Epoch 2/20
# 28/28 [==============================] - 33s 1s/step - loss: 525.9400 - accuracy: 0.7392 - recall: 0.7392 - val_loss: 1153.1317 - val_accuracy: 0.5388 - val_recall: 0.5388
# 28/28 [==============================] - 32s 1s/step - loss: 4.9600 - accuracy: 0.9852 - recall: 0.9852 - val_loss: 403.2253 - val_accuracy: 0.4703 - val_recall: 0.4703
# Epoch 19/20
# 28/28 [==============================] - 30s 1s/step - loss: 3.1017 - accuracy: 0.9909 - recall: 0.9909 - val_loss: 468.3177 - val_accuracy: 0.5297 - val_recall: 0.5297
# Epoch 20/20
# 28/28 [==============================] - 30s 1s/step - loss: 6.6242 - accuracy: 0.9818 - recall: 0.9818 - val_loss: 518.5128 - val_accuracy: 0.4703 - val_recall: 0.4703

# %% [markdown]
# ### CNN Model without Data Augmentation

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Conv2D(16, (3,3), activation = 'relu', input_shape = (300,300,3)),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(32, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(64, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(128, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(256, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(512, activation = 'relu'),
     tf.keras.layers.Dense(1024, activation = 'relu'),
     tf.keras.layers.Dense(3, activation = 'softmax')
    ]
)

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy',tf.keras.metrics.Recall()])
history2 = model.fit(
      train_generator,
      epochs=20,
      verbose=1,
      validation_data = test_generator)
# Out:
# Epoch 1/20
# 28/28 [==============================] - 93s 3s/step - loss: 16.1601 - accuracy: 0.4487 - recall_1: 0.3838 - val_loss: 1.0394 - val_accuracy: 0.6256 - val_recall_1: 0.5434
# Epoch 2/20
# 28/28 [==============================] - 93s 3s/step - loss: 0.8398 - accuracy: 0.6241 - recall_1: 0.5159 - val_loss: 0.9154 - val_accuracy: 0.5662 - val_recall_1: 0.5342
# Epoch 3/20
# 28/28 [==============================] - 93s 3s/step - loss: 0.6514 - accuracy: 0.7267 - recall_1: 0.6606 - val_loss: 1.0035 - val_accuracy: 0.5936 - val_recall_1: 0.5571
# Epoch 4/20
# 28/28 [==============================] - 92s 3s/step - loss: 0.3760 - accuracy: 0.8679 - recall_1: 0.8371 - val_loss: 1.0479 - val_accuracy: 0.6621 - val_recall_1: 0.6393
# Epoch 5/20
# 28/28 [==============================] - 92s 3s/step - loss: 0.2743 - accuracy: 0.8918 - recall_1: 0.8759 - val_loss: 1.3421 - val_accuracy: 0.6164 - val_recall_1: 0.6027
# Epoch 6/20
# 28/28 [==============================] - 91s 3s/step - loss: 0.1276 - accuracy: 0.9636 - recall_1: 0.9567 - val_loss: 1.0381 - val_accuracy: 0.6210 - val_recall_1: 0.6073
# Epoch 7/20
# 28/28 [==============================] - 91s 3s/step - loss: 0.0562 - accuracy: 0.9829 - recall_1: 0.9829 - val_loss: 0.8999 - val_accuracy: 0.8128 - val_recall_1: 0.8037
# Epoch 8/20
# 28/28 [==============================] - 91s 3s/step - loss: 0.0480 - accuracy: 0.9886 - recall_1: 0.9886 - val_loss: 0.7385 - val_accuracy: 0.7808 - val_recall_1: 0.7763
# Epoch 9/20
# 28/28 [==============================] - 92s 3s/step - loss: 0.0158 - accuracy: 0.9943 - recall_1: 0.9943 - val_loss: 1.0419 - val_accuracy: 0.7763 - val_recall_1: 0.7763
# Epoch 10/20
# 28/28 [==============================] - 92s 3s/step - loss: 0.0124 - accuracy: 0.9943 - recall_1: 0.9943 - val_loss: 1.3084 - val_accuracy: 0.7763 - val_recall_1: 0.7763
# Epoch 11/20
# 28/28 [==============================] - 92s 3s/step - loss: 0.0194 - accuracy: 0.9966 - recall_1: 0.9966 - val_loss: 1.0130 - val_accuracy: 0.7580 - val_recall_1: 0.7580
# Epoch 12/20
# 28/28 [==============================] - 92s 3s/step - loss: 0.0107 - accuracy: 0.9966 - recall_1: 0.9966 - val_loss: 1.3119 - val_accuracy: 0.7854 - val_recall_1: 0.7854
# Epoch 13/20
# 28/28 [==============================] - 92s 3s/step - loss: 0.1045 - accuracy: 0.9647 - recall_1: 0.9647 - val_loss: 1.4948 - val_accuracy: 0.7489 - val_recall_1: 0.7443
# Epoch 14/20
# 28/28 [==============================] - 92s 3s/step - loss: 0.1152 - accuracy: 0.9624 - recall_1: 0.9613 - val_loss: 1.5927 - val_accuracy: 0.6895 - val_recall_1: 0.6849
# Epoch 15/20
# 28/28 [==============================] - 92s 3s/step - loss: 0.0353 - accuracy: 0.9863 - recall_1: 0.9852 - val_loss: 1.3689 - val_accuracy: 0.6484 - val_recall_1: 0.6484
# Epoch 16/20
# 28/28 [==============================] - 92s 3s/step - loss: 0.0443 - accuracy: 0.9875 - recall_1: 0.9875 - val_loss: 1.4843 - val_accuracy: 0.6393 - val_recall_1: 0.6301
# Epoch 17/20
# 28/28 [==============================] - 92s 3s/step - loss: 0.0102 - accuracy: 0.9954 - recall_1: 0.9954 - val_loss: 1.1470 - val_accuracy: 0.7763 - val_recall_1: 0.7717
# Epoch 18/20
# 28/28 [==============================] - 100s 4s/step - loss: 0.0089 - accuracy: 0.9966 - recall_1: 0.9966 - val_loss: 1.2618 - val_accuracy: 0.7991 - val_recall_1: 0.7945
# Epoch 19/20
# 28/28 [==============================] - 97s 3s/step - loss: 0.0071 - accuracy: 0.9977 - recall_1: 0.9977 - val_loss: 1.3277 - val_accuracy: 0.7854 - val_recall_1: 0.7763
# Epoch 20/20
# 28/28 [==============================] - 93s 3s/step - loss: 0.0035 - accuracy: 0.9977 - recall_1: 0.9977 - val_loss: 1.4483 - val_accuracy: 0.7763 - val_recall_1: 0.7763

# %% [markdown]
# ### CNN Model with Data Augmentation

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Conv2D(16, (3,3), activation = 'relu', input_shape = (300,300,3)),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(32, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(64, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(128, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(256, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(512, activation = 'relu'),
     tf.keras.layers.Dense(1024, activation = 'relu'),
     tf.keras.layers.Dense(3, activation = 'softmax')
    ]
)

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy',tf.keras.metrics.Recall()])
history3 = model.fit(
      train_generator_ia,
      epochs=20,
      verbose=1,
      validation_data = test_generator_ia)
      # pass tracing
  #    callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 28/28 [==============================] - 117s 4s/step - loss: 0.9894 - accuracy: 0.4863 - recall_2: 0.2631 - val_loss: 0.9656 - val_accuracy: 0.5114 - val_recall_2: 0.5114
# Epoch 2/20
# 28/28 [==============================] - 110s 4s/step - loss: 0.9148 - accuracy: 0.5524 - recall_2: 0.3576 - val_loss: 0.9672 - val_accuracy: 0.5479 - val_recall_2: 0.5114
# Epoch 3/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.7670 - accuracy: 0.6856 - recall_2: 0.6082 - val_loss: 1.0424 - val_accuracy: 0.5753 - val_recall_2: 0.5160
# Epoch 4/20
# 28/28 [==============================] - 111s 4s/step - loss: 0.7132 - accuracy: 0.7005 - recall_2: 0.6287 - val_loss: 0.9290 - val_accuracy: 0.6256 - val_recall_2: 0.5068
# Epoch 5/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.6886 - accuracy: 0.7335 - recall_2: 0.6640 - val_loss: 1.0185 - val_accuracy: 0.6027 - val_recall_2: 0.5753
# Epoch 6/20
# 28/28 [==============================] - 116s 4s/step - loss: 0.6045 - accuracy: 0.7642 - recall_2: 0.7084 - val_loss: 1.0111 - val_accuracy: 0.6575 - val_recall_2: 0.6438
# Epoch 7/20
# 28/28 [==============================] - 115s 4s/step - loss: 0.6743 - accuracy: 0.7289 - recall_2: 0.6481 - val_loss: 1.1359 - val_accuracy: 0.5936 - val_recall_2: 0.5388
# Epoch 8/20
# 28/28 [==============================] - 110s 4s/step - loss: 0.5099 - accuracy: 0.7984 - recall_2: 0.7574 - val_loss: 1.0388 - val_accuracy: 0.6667 - val_recall_2: 0.6347
# Epoch 9/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.5252 - accuracy: 0.8109 - recall_2: 0.7506 - val_loss: 0.8121 - val_accuracy: 0.6941 - val_recall_2: 0.5297
# Epoch 10/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.4151 - accuracy: 0.8485 - recall_2: 0.8121 - val_loss: 0.7315 - val_accuracy: 0.8174 - val_recall_2: 0.7854
# Epoch 11/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.4065 - accuracy: 0.8314 - recall_2: 0.8144 - val_loss: 0.7427 - val_accuracy: 0.7717 - val_recall_2: 0.7078
# Epoch 12/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.3323 - accuracy: 0.8622 - recall_2: 0.8417 - val_loss: 0.6567 - val_accuracy: 0.8174 - val_recall_2: 0.7808
# Epoch 13/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.5376 - accuracy: 0.7836 - recall_2: 0.7289 - val_loss: 0.8529 - val_accuracy: 0.7534 - val_recall_2: 0.6621
# Epoch 14/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.4613 - accuracy: 0.8178 - recall_2: 0.7813 - val_loss: 0.6991 - val_accuracy: 0.7991 - val_recall_2: 0.7306
# Epoch 15/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.4069 - accuracy: 0.8371 - recall_2: 0.8052 - val_loss: 0.7030 - val_accuracy: 0.7763 - val_recall_2: 0.6986
# Epoch 16/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.3515 - accuracy: 0.8565 - recall_2: 0.8257 - val_loss: 0.9441 - val_accuracy: 0.7306 - val_recall_2: 0.6758
# Epoch 17/20
# 28/28 [==============================] - 112s 4s/step - loss: 0.3260 - accuracy: 0.8679 - recall_2: 0.8383 - val_loss: 0.7954 - val_accuracy: 0.7169 - val_recall_2: 0.6941
# Epoch 18/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.3096 - accuracy: 0.8622 - recall_2: 0.8440 - val_loss: 0.7382 - val_accuracy: 0.7808 - val_recall_2: 0.7443
# Epoch 19/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.2713 - accuracy: 0.8804 - recall_2: 0.8622 - val_loss: 0.9702 - val_accuracy: 0.7900 - val_recall_2: 0.7763
# Epoch 20/20
# 28/28 [==============================] - 109s 4s/step - loss: 0.2760 - accuracy: 0.8770 - recall_2: 0.8576 - val_loss: 1.0711 - val_accuracy: 0.7991 - val_recall_2: 0.7763

# %%
# %tensorboard --logdir logs/fit

# %% [markdown]
# ### CNN Model with Data Augmentation and Normalization

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Conv2D(16, (3,3), activation = 'relu', input_shape = (300,300,3)),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Conv2D(32, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(64, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Conv2D(128, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Conv2D(256, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(512, activation = 'relu'),
     tf.keras.layers.Dense(1024, activation = 'relu'),
     tf.keras.layers.Dropout(0.3),
     tf.keras.layers.Dense(3, activation = 'softmax')
    ]
)

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy',tf.keras.metrics.Recall()])
history4 = model.fit(
      train_generator_ia,
      epochs=20,
      verbose=1,
      validation_data = test_generator_ia)
# Out:
# Epoch 1/20
# 28/28 [==============================] - 121s 4s/step - loss: 1.3721 - accuracy: 0.6298 - recall_3: 0.6059 - val_loss: 1.8872 - val_accuracy: 0.5114 - val_recall_3: 0.5114
# Epoch 2/20
# 28/28 [==============================] - 116s 4s/step - loss: 0.6978 - accuracy: 0.7301 - recall_3: 0.7130 - val_loss: 8.9387 - val_accuracy: 0.5114 - val_recall_3: 0.5114
# Epoch 3/20
# 28/28 [==============================] - 120s 4s/step - loss: 0.5033 - accuracy: 0.8087 - recall_3: 0.7847 - val_loss: 6.2844 - val_accuracy: 0.5114 - val_recall_3: 0.5114
# Epoch 4/20
# 28/28 [==============================] - 117s 4s/step - loss: 0.3813 - accuracy: 0.8440 - recall_3: 0.8303 - val_loss: 18.4802 - val_accuracy: 0.5114 - val_recall_3: 0.5114
# Epoch 5/20
# 28/28 [==============================] - 115s 4s/step - loss: 0.4350 - accuracy: 0.8394 - recall_3: 0.8235 - val_loss: 43.5431 - val_accuracy: 0.5114 - val_recall_3: 0.5114
# Epoch 6/20
# 28/28 [==============================] - 116s 4s/step - loss: 0.4537 - accuracy: 0.8109 - recall_3: 0.7870 - val_loss: 21.5491 - val_accuracy: 0.5114 - val_recall_3: 0.5114
# Epoch 7/20
# 28/28 [==============================] - 116s 4s/step - loss: 0.4959 - accuracy: 0.8121 - recall_3: 0.7893 - val_loss: 6.9517 - val_accuracy: 0.5160 - val_recall_3: 0.5160
# Epoch 8/20
# 28/28 [==============================] - 116s 4s/step - loss: 0.3855 - accuracy: 0.8474 - recall_3: 0.8383 - val_loss: 3.7875 - val_accuracy: 0.4886 - val_recall_3: 0.4886
# Epoch 9/20
# 28/28 [==============================] - 115s 4s/step - loss: 0.4621 - accuracy: 0.8428 - recall_3: 0.8292 - val_loss: 7.3506 - val_accuracy: 0.5114 - val_recall_3: 0.5114
# Epoch 10/20
# 28/28 [==============================] - 118s 4s/step - loss: 0.3380 - accuracy: 0.8554 - recall_3: 0.8451 - val_loss: 5.5445 - val_accuracy: 0.4475 - val_recall_3: 0.4475
# Epoch 11/20
# 28/28 [==============================] - 122s 4s/step - loss: 0.3022 - accuracy: 0.8599 - recall_3: 0.8451 - val_loss: 7.7240 - val_accuracy: 0.3836 - val_recall_3: 0.3836
# Epoch 12/20
# 28/28 [==============================] - 118s 4s/step - loss: 0.3654 - accuracy: 0.8474 - recall_3: 0.8349 - val_loss: 10.6548 - val_accuracy: 0.3790 - val_recall_3: 0.3790
# Epoch 13/20
# 28/28 [==============================] - 120s 4s/step - loss: 0.3358 - accuracy: 0.8576 - recall_3: 0.8451 - val_loss: 9.5907 - val_accuracy: 0.3973 - val_recall_3: 0.3973
# Epoch 14/20
# 28/28 [==============================] - 116s 4s/step - loss: 0.2789 - accuracy: 0.8815 - recall_3: 0.8747 - val_loss: 7.3403 - val_accuracy: 0.4292 - val_recall_3: 0.4292
# Epoch 15/20
# 28/28 [==============================] - 115s 4s/step - loss: 0.2995 - accuracy: 0.8690 - recall_3: 0.8633 - val_loss: 7.7099 - val_accuracy: 0.3881 - val_recall_3: 0.3881
# Epoch 16/20
# 28/28 [==============================] - 117s 4s/step - loss: 0.2726 - accuracy: 0.8861 - recall_3: 0.8747 - val_loss: 12.7436 - val_accuracy: 0.3836 - val_recall_3: 0.3836
# Epoch 17/20
# 28/28 [==============================] - 121s 4s/step - loss: 0.2994 - accuracy: 0.8645 - recall_3: 0.8508 - val_loss: 7.9390 - val_accuracy: 0.3927 - val_recall_3: 0.3927
# Epoch 18/20
# 28/28 [==============================] - 120s 4s/step - loss: 0.3621 - accuracy: 0.8565 - recall_3: 0.8474 - val_loss: 15.4991 - val_accuracy: 0.3790 - val_recall_3: 0.3790
# Epoch 19/20
# 28/28 [==============================] - 117s 4s/step - loss: 0.3884 - accuracy: 0.8314 - recall_3: 0.8144 - val_loss: 18.7742 - val_accuracy: 0.3790 - val_recall_3: 0.3790
# Epoch 20/20
# 28/28 [==============================] - 116s 4s/step - loss: 0.3013 - accuracy: 0.8759 - recall_3: 0.8588 - val_loss: 12.8792 - val_accuracy: 0.3790 - val_recall_3: 0.3790

# %% [markdown]
# ### LSTM Network

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Conv2D(16, (3,3), activation = 'relu', input_shape = (300,300,3)),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Conv2D(32, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(64, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Conv2D(128, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Conv2D(256, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Reshape((7,7*256)),
     tf.keras.layers.LSTM(128),

     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(512, activation = 'relu'),
     tf.keras.layers.Dense(1024, activation = 'relu'),
     tf.keras.layers.Dropout(0.3),
     tf.keras.layers.Dense(3, activation = 'softmax')
    ]
)

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy',tf.keras.metrics.Recall()])
history5 = model.fit(
      train_generator_ia,
      epochs=20,
      verbose=1,
      validation_data = test_generator_ia)
# Out:
# Epoch 1/20
# 28/28 [==============================] - 122s 4s/step - loss: 0.6867 - accuracy: 0.7118 - recall_4: 0.6526 - val_loss: 0.9576 - val_accuracy: 0.4155 - val_recall_4: 0.2009
# Epoch 2/20
# 28/28 [==============================] - 118s 4s/step - loss: 0.4843 - accuracy: 0.7995 - recall_4: 0.7563 - val_loss: 0.9241 - val_accuracy: 0.4110 - val_recall_4: 0.3927
# Epoch 3/20
# 28/28 [==============================] - 124s 4s/step - loss: 0.4018 - accuracy: 0.8292 - recall_4: 0.7984 - val_loss: 0.8496 - val_accuracy: 0.6073 - val_recall_4: 0.5342
# Epoch 4/20
# 28/28 [==============================] - 119s 4s/step - loss: 0.3990 - accuracy: 0.8292 - recall_4: 0.8052 - val_loss: 3.0140 - val_accuracy: 0.3790 - val_recall_4: 0.3790
# Epoch 5/20
# 28/28 [==============================] - 117s 4s/step - loss: 0.4449 - accuracy: 0.8269 - recall_4: 0.7973 - val_loss: 2.4698 - val_accuracy: 0.3790 - val_recall_4: 0.3790
# Epoch 6/20
# 28/28 [==============================] - 115s 4s/step - loss: 0.3730 - accuracy: 0.8451 - recall_4: 0.8246 - val_loss: 2.5643 - val_accuracy: 0.3790 - val_recall_4: 0.3790
# Reference: https://medium.com/mlearning-ai/implementation-of-googlenet-on-keras-d9873aeed83c

# %%
def inception_block(input, path1_filters, path2_filters, path3_filters, path4_filters):
  # First path:
  path1 = tf.keras.layers.Conv2D(filters = path1_filters, kernel_size = (1,1), padding = 'same', activation = 'relu')(input)

  # Second path
  path2 = tf.keras.layers.Conv2D(filters = path2_filters[0], kernel_size = (1,1), padding = 'same', activation = 'relu')(input)
  path2 = tf.keras.layers.Conv2D(filters = path2_filters[1], kernel_size = (3,3), padding = 'same', activation = 'relu')(path2)

  # Third path
  path3 = tf.keras.layers.Conv2D(filters = path3_filters[0], kernel_size = (1,1), padding = 'same', activation = 'relu')(input)
  path3 = tf.keras.layers.Conv2D(filters = path3_filters[1], kernel_size = (5,5), padding = 'same', activation = 'relu')(path3)

  # 4th path
  path4 = tf.keras.layers.MaxPooling2D((3,3), strides= (1,1), padding = 'same')(input)
  path4 = tf.keras.layers.Conv2D(filters = path4_filters, kernel_size = (1,1), padding = 'same', activation = 'relu')(path4)

  output_layer = tf.keras.layers.concatenate([path1, path2, path3, path4], axis = -1)

  return output_layer

# %%
def GoogLeNet():
  # Define the input layer with an input size equal to the size of the images
  input = tf.keras.layers.Input(shape = (300, 300, 3))

  # First Conv2D layer: filters = 64, kernel_size = (7,7), strides = 2
  X = tf.keras.layers.Conv2D(filters = 64, kernel_size = (7,7), strides = 2, padding = 'valid', activation = 'relu')(input)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = tf.keras.layers.MaxPooling2D(pool_size = (3,3), strides = 2)(X)

  # convolutional layer: filters = 64, strides = 1
  X = tf.keras.layers.Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding = 'same', activation = 'relu')(X)

  # convolutional layer: filters = 192, kernel_size = (3,3)
  X = tf.keras.layers.Conv2D(filters = 192, kernel_size = (3,3), padding = 'same', activation = 'relu')(X)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = tf.keras.layers.MaxPooling2D(pool_size= (3,3), strides = 2)(X)

  # 1st Inception block
  X = inception_block(X, path1_filters = 64, path2_filters = (96, 128), path3_filters = (16, 32), path4_filters = 32)

  # 2nd Inception block
  X = inception_block(X, path1_filters = 128, path2_filters = (128, 192), path3_filters = (32, 96), path4_filters = 64)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = tf.keras.layers.MaxPooling2D(pool_size= (3,3), strides = 2)(X)

  # 3rd Inception block
  X = inception_block(X, path1_filters = 192, path2_filters = (96, 208), path3_filters = (16, 48), path4_filters = 64)

  # Extra network 1:
  X1 = tf.keras.layers.AveragePooling2D(pool_size = (5,5), strides = 3)(X)
  X1 = tf.keras.layers.Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X1)
  X1 = tf.keras.layers.Flatten()(X1)
  X1 = tf.keras.layers.Dense(1024, activation = 'relu')(X1)
  X1 = tf.keras.layers.Dropout(0.7)(X1)
  X1 = tf.keras.layers.Dense(3, activation = 'softmax', name = 'Extra_Network_1')(X1)

  
  # 4th Inception block
  X = inception_block(X, path1_filters = 160, path2_filters = (112, 224), path3_filters= (24, 64), path4_filters = 64)

  # 5th Inception block
  X = inception_block(X, path1_filters = 128, path2_filters = (128, 256), path3_filters = (24, 64), path4_filters = 64)

  # 6th Inception block
  X = inception_block(X, path1_filters = 112, path2_filters = (144, 288), path3_filters = (32, 64), path4_filters = 64)

  # Extra network 2:
  X2 = tf.keras.layers.AveragePooling2D(pool_size = (5,5), strides = 3)(X)
  X2 = tf.keras.layers.Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X2)
  X2 = tf.keras.layers.Flatten()(X2)
  X2 = tf.keras.layers.Dense(1024, activation = 'relu')(X2)
  X2 = tf.keras.layers.Dropout(0.7)(X2)
  X2 = tf.keras.layers.Dense(3, activation = 'softmax', name = 'Extra_Network_2')(X2)
  
  
  # 7th Inception block
  X = inception_block(X, path1_filters = 256, path2_filters = (160, 320), path3_filters = (32, 128), path4_filters = 128)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = tf.keras.layers.MaxPooling2D(pool_size = (3,3), strides = 2)(X)

  # 8th Inception block
  X = inception_block(X, path1_filters = 256, path2_filters = (160, 320), path3_filters = (32, 128), path4_filters = 128)

  # 9th Inception block
  X = inception_block(X, path1_filters = 384, path2_filters = (192, 384), path3_filters = (48, 128), path4_filters = 128)

  # Global Average pooling layer 
  X = tf.keras.layers.GlobalAveragePooling2D(name = 'GAPL')(X)

  # Dropoutlayer 
  X = tf.keras.layers.Dropout(0.4)(X)

  # output layer 
  X = tf.keras.layers.Dense(3, activation = 'softmax', name = 'Output')(X)
  
  # model
  model = tf.keras.Model(input, [X, X1, X2], name = 'GoogLeNet')

  return model

# %%
model = GoogLeNet()
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy',tf.keras.metrics.Recall()])
history = model.fit(train_generator_ia, epochs = 20, verbose=1, validation_data = test_generator_ia)

# %% [markdown]
# ### Plot accuracies and losses

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize=(15,15))
axes[0,0].plot(history1.history['accuracy'], label = 'Base model')
axes[0,0].plot(history2.history['accuracy'], label = 'CNN model without DA')
axes[0,0].plot(history3.history['accuracy'], label = 'CNN model with DA')
axes[0,0].plot(history4.history['accuracy'], label = 'CNN model with DA and Norm.')
axes[0,0].plot(history5.history['accuracy'], label = 'LSTM model')
axes[0,0].plot(history.history['Output_accuracy'], label = 'GoogLeNet')
axes[0,0].set_xlabel('Epoch')
axes[0,0].set_ylabel('Accuracy')

axes[1,0].plot(history1.history['val_accuracy'], label = 'Base model')
axes[1,0].plot(history2.history['val_accuracy'], label = 'CNN model without DA')
axes[1,0].plot(history3.history['val_accuracy'], label = 'CNN model with DA')
axes[1,0].plot(history4.history['val_accuracy'], label = 'CNN model with DA and Norm.')
axes[1,0].plot(history5.history['val_accuracy'], label = 'LSTM model')
axes[0,0].plot(history.history['val_Output_accuracy'], label = 'GoogLeNet')
axes[1,0].set_xlabel('Epoch')
axes[1,0].set_ylabel('Val. Accuracy')

axes[0,1].plot(history1.history['loss'], label = 'Base model')
axes[0,1].plot(history2.history['loss'], label = 'CNN model without DA')
axes[0,1].plot(history3.history['loss'], label = 'CNN model with DA')
axes[0,1].plot(history4.history['loss'], label = 'CNN model with DA and Norm.')
axes[0,1].plot(history5.history['loss'], label = 'LSTM model')
axes[0,0].plot(history.history['Output_loss'], label = 'GoogLeNet')
axes[0,1].set_xlabel('Epoch')
axes[0,1].set_ylabel('Loss')

axes[1,1].plot(history1.history['val_loss'], label = 'Base model')
axes[1,1].plot(history2.history['val_loss'], label = 'CNN model without DA')
axes[1,1].plot(history3.history['val_loss'], label = 'CNN model with DA')
axes[1,1].plot(history4.history['val_loss'], label = 'CNN model with DA and Norm.')
axes[1,1].plot(history5.history['val_loss'], label = 'LSTM model')
axes[0,0].plot(history.history['val_Output_loss'], label = 'GoogLeNet')
axes[1,1].set_xlabel('Epoch')
axes[1,1].set_ylabel('Val. Loss')

plt.legend()
plt.show()

# %% [markdown]
# We can see that the CNN model with Data Augmentation is the one with the highest accuracies (training and validation accuracies) and the smallest loss values.

# %% [markdown]
# # Binary Classifier implementation -

# %%
# binary classifier malignant/non-malignant data
# !gdown 1lhWypCSTFOECH_9R3WseFeBBse9pXH5A
# https://drive.google.com/file/d/1lhWypCSTFOECH_9R3WseFeBBse9pXH5A/view?usp=sharing
# https://drive.google.com/file/d/1lhWypCSTFOECH_9R3WseFeBBse9pXH5A/view?usp=sharing

# %%
# binary category data
# !unzip "binary_classifier_data.zip"

# %% [markdown]
# ### Load images using an ImageDataGenerator. With this object we also apply augmentation

# %% [markdown]
# ### We will create two copies of the training and validation datasets. One will contain Data Augmentation while the others won't

# %%
datagen = ImageDataGenerator(validation_split=0.2)

datagen_ia = ImageDataGenerator(
    rescale = 1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip = True,
    fill_mode = 'nearest',
    validation_split=0.2)

train_generator = datagen.flow_from_directory('binary_classifier_data/',
                                              target_size = (300,300),
                                              class_mode = 'categorical',
                                              subset='training')

test_generator = datagen.flow_from_directory('binary_classifier_data/',
                                              target_size = (300,300),
                                              class_mode = 'categorical',
                                              subset='validation')

train_generator_ia = datagen_ia.flow_from_directory('binary_classifier_data/',
                                              target_size = (300,300),
                                              class_mode = 'categorical',
                                              subset='training')

test_generator_ia = datagen_ia.flow_from_directory('binary_classifier_data/',
                                              target_size = (300,300),
                                              class_mode = 'categorical',
                                              subset='validation')

# %% [markdown]
# ### Base Model

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten()) # Flattens the input to 1D
model.add(tf.keras.layers.Dense(512, activation = 'relu'))
model.add(tf.keras.layers.Dense(1024, activation = 'relu'))
model.add(tf.keras.layers.Dense(2, activation = 'softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

history1 = model.fit(
      train_generator,
      epochs=20,
      verbose=1,
      validation_data = test_generator)

# %% [markdown]
# ### CNN Model without Data Augmentation

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Conv2D(16, (3,3), activation = 'relu', input_shape = (300,300,3)),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(32, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(64, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(128, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(256, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(512, activation = 'relu'),
     tf.keras.layers.Dense(1024, activation = 'relu'),
     tf.keras.layers.Dense(2, activation = 'softmax')
    ]
)

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
history2 = model.fit(
      train_generator,
      epochs=20,
      verbose=1,
      validation_data = test_generator)

# %% [markdown]
# ### CNN Model with Data Augmentation

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Conv2D(16, (3,3), activation = 'relu', input_shape = (300,300,3)),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(32, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(64, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(128, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(256, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(512, activation = 'relu'),
     tf.keras.layers.Dense(1024, activation = 'relu'),
     tf.keras.layers.Dense(2, activation = 'softmax')
    ]
)

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
history3 = model.fit(
      train_generator_ia,
      epochs=20,
      verbose=1,
      validation_data = test_generator_ia)f

# %% [markdown]
# ### CNN Model with Data Augmentation and Normalization

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Conv2D(16, (3,3), activation = 'relu', input_shape = (300,300,3)),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Conv2D(32, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(64, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Conv2D(128, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Conv2D(256, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(512, activation = 'relu'),
     tf.keras.layers.Dense(1024, activation = 'relu'),
     tf.keras.layers.Dropout(0.3),
     tf.keras.layers.Dense(2, activation = 'softmax')
    ]
)

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
history4 = model.fit(
      train_generator_ia,
      epochs=20,
      verbose=1,
      validation_data = test_generator_ia)

# %% [markdown]
# ### LSTM Network

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Conv2D(16, (3,3), activation = 'relu', input_shape = (300,300,3)),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Conv2D(32, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),

     tf.keras.layers.Conv2D(64, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Conv2D(128, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Conv2D(256, (3,3), activation = 'relu'),
     tf.keras.layers.MaxPooling2D(2,2),
     tf.keras.layers.BatchNormalization(),

     tf.keras.layers.Reshape((7,7*256)),
     tf.keras.layers.LSTM(128),

     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(512, activation = 'relu'),
     tf.keras.layers.Dense(1024, activation = 'relu'),
     tf.keras.layers.Dropout(0.3),
     tf.keras.layers.Dense(2, activation = 'softmax')
    ]
)

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
history5 = model.fit(
      train_generator_ia,
      epochs=20,
      verbose=1,
      validation_data = test_generator_ia)

# %% [markdown]
# ### GoogLeNet
# GooLeNet consist of 22 layers, 9 inception blocks and 3 softmax outputs
#
# Reference: https://medium.com/mlearning-ai/implementation-of-googlenet-on-keras-d9873aeed83c

# %%
def inception_block(input, path1_filters, path2_filters, path3_filters, path4_filters):
  # First path:
  path1 = tf.keras.layers.Conv2D(filters = path1_filters, kernel_size = (1,1), padding = 'same', activation = 'relu')(input)

  # Second path
  path2 = tf.keras.layers.Conv2D(filters = path2_filters[0], kernel_size = (1,1), padding = 'same', activation = 'relu')(input)
  path2 = tf.keras.layers.Conv2D(filters = path2_filters[1], kernel_size = (3,3), padding = 'same', activation = 'relu')(path2)

  # Third path
  path3 = tf.keras.layers.Conv2D(filters = path3_filters[0], kernel_size = (1,1), padding = 'same', activation = 'relu')(input)
  path3 = tf.keras.layers.Conv2D(filters = path3_filters[1], kernel_size = (5,5), padding = 'same', activation = 'relu')(path3)

  # 4th path
  path4 = tf.keras.layers.MaxPooling2D((3,3), strides= (1,1), padding = 'same')(input)
  path4 = tf.keras.layers.Conv2D(filters = path4_filters, kernel_size = (1,1), padding = 'same', activation = 'relu')(path4)

  output_layer = tf.keras.layers.concatenate([path1, path2, path3, path4], axis = -1)

  return output_layer

# %%
def GoogLeNet():
  # Define the input layer with an input size equal to the size of the images
  input = tf.keras.layers.Input(shape = (300, 300, 3))

  # First Conv2D layer: filters = 64, kernel_size = (7,7), strides = 2
  X = tf.keras.layers.Conv2D(filters = 64, kernel_size = (7,7), strides = 2, padding = 'valid', activation = 'relu')(input)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = tf.keras.layers.MaxPooling2D(pool_size = (3,3), strides = 2)(X)

  # convolutional layer: filters = 64, strides = 1
  X = tf.keras.layers.Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding = 'same', activation = 'relu')(X)

  # convolutional layer: filters = 192, kernel_size = (3,3)
  X = tf.keras.layers.Conv2D(filters = 192, kernel_size = (3,3), padding = 'same', activation = 'relu')(X)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = tf.keras.layers.MaxPooling2D(pool_size= (3,3), strides = 2)(X)

  # 1st Inception block
  X = inception_block(X, path1_filters = 64, path2_filters = (96, 128), path3_filters = (16, 32), path4_filters = 32)

  # 2nd Inception block
  X = inception_block(X, path1_filters = 128, path2_filters = (128, 192), path3_filters = (32, 96), path4_filters = 64)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = tf.keras.layers.MaxPooling2D(pool_size= (3,3), strides = 2)(X)

  # 3rd Inception block
  X = inception_block(X, path1_filters = 192, path2_filters = (96, 208), path3_filters = (16, 48), path4_filters = 64)

  # Extra network 1:
  X1 = tf.keras.layers.AveragePooling2D(pool_size = (5,5), strides = 3)(X)
  X1 = tf.keras.layers.Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X1)
  X1 = tf.keras.layers.Flatten()(X1)
  X1 = tf.keras.layers.Dense(1024, activation = 'relu')(X1)
  X1 = tf.keras.layers.Dropout(0.7)(X1)
  X1 = tf.keras.layers.Dense(2, activation = 'softmax', name = 'Extra_Network_1')(X1)

  
  # 4th Inception block
  X = inception_block(X, path1_filters = 160, path2_filters = (112, 224), path3_filters= (24, 64), path4_filters = 64)

  # 5th Inception block
  X = inception_block(X, path1_filters = 128, path2_filters = (128, 256), path3_filters = (24, 64), path4_filters = 64)

  # 6th Inception block
  X = inception_block(X, path1_filters = 112, path2_filters = (144, 288), path3_filters = (32, 64), path4_filters = 64)

  # Extra network 2:
  X2 = tf.keras.layers.AveragePooling2D(pool_size = (5,5), strides = 3)(X)
  X2 = tf.keras.layers.Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X2)
  X2 = tf.keras.layers.Flatten()(X2)
  X2 = tf.keras.layers.Dense(1024, activation = 'relu')(X2)
  X2 = tf.keras.layers.Dropout(0.7)(X2)
  X2 = tf.keras.layers.Dense(2, activation = 'softmax', name = 'Extra_Network_2')(X2)
  
  
  # 7th Inception block
  X = inception_block(X, path1_filters = 256, path2_filters = (160, 320), path3_filters = (32, 128), path4_filters = 128)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = tf.keras.layers.MaxPooling2D(pool_size = (3,3), strides = 2)(X)

  # 8th Inception block
  X = inception_block(X, path1_filters = 256, path2_filters = (160, 320), path3_filters = (32, 128), path4_filters = 128)

  # 9th Inception block
  X = inception_block(X, path1_filters = 384, path2_filters = (192, 384), path3_filters = (48, 128), path4_filters = 128)

  # Global Average pooling layer 
  X = tf.keras.layers.GlobalAveragePooling2D(name = 'GAPL')(X)

  # Dropoutlayer 
  X = tf.keras.layers.Dropout(0.4)(X)

  # output layer 
  X = tf.keras.layers.Dense(2, activation = 'softmax', name = 'Output')(X)
  
  # model
  model = tf.keras.Model(input, [X, X1, X2], name = 'GoogLeNet')

  return model

# %%
model = GoogLeNet()
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
history = model.fit(train_generator_ia, epochs = 20, verbose=1, validation_data = test_generator_ia)

# %% [markdown]
# ### Plot accuracies and losses

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize=(15,15))
axes[0,0].plot(history1.history['accuracy'], label = 'Base model')
axes[0,0].plot(history2.history['accuracy'], label = 'CNN model without DA')
axes[0,0].plot(history3.history['accuracy'], label = 'CNN model with DA')
axes[0,0].plot(history4.history['accuracy'], label = 'CNN model with DA and Norm.')
axes[0,0].plot(history5.history['accuracy'], label = 'LSTM model')
axes[0,0].plot(history.history['Output_accuracy'], label = 'GoogLeNet')
axes[0,0].set_xlabel('Epoch')
axes[0,0].set_ylabel('Accuracy')

axes[1,0].plot(history1.history['val_accuracy'], label = 'Base model')
axes[1,0].plot(history2.history['val_accuracy'], label = 'CNN model without DA')
axes[1,0].plot(history3.history['val_accuracy'], label = 'CNN model with DA')
axes[1,0].plot(history4.history['val_accuracy'], label = 'CNN model with DA and Norm.')
axes[1,0].plot(history5.history['val_accuracy'], label = 'LSTM model')
axes[0,0].plot(history.history['val_Output_accuracy'], label = 'GoogLeNet')
axes[1,0].set_xlabel('Epoch')
axes[1,0].set_ylabel('Val. Accuracy')

axes[0,1].plot(history1.history['loss'], label = 'Base model')
axes[0,1].plot(history2.history['loss'], label = 'CNN model without DA')
axes[0,1].plot(history3.history['loss'], label = 'CNN model with DA')
axes[0,1].plot(history4.history['loss'], label = 'CNN model with DA and Norm.')
axes[0,1].plot(history5.history['loss'], label = 'LSTM model')
axes[0,0].plot(history.history['Output_loss'], label = 'GoogLeNet')
axes[0,1].set_xlabel('Epoch')
axes[0,1].set_ylabel('Loss')

axes[1,1].plot(history1.history['val_loss'], label = 'Base model')
axes[1,1].plot(history2.history['val_loss'], label = 'CNN model without DA')
axes[1,1].plot(history3.history['val_loss'], label = 'CNN model with DA')
axes[1,1].plot(history4.history['val_loss'], label = 'CNN model with DA and Norm.')
axes[1,1].plot(history5.history['val_loss'], label = 'LSTM model')
axes[0,0].plot(history.history['val_Output_loss'], label = 'GoogLeNet')
axes[1,1].set_xlabel('Epoch')
axes[1,1].set_ylabel('Val. Loss')

plt.legend()
plt.show()

# %% [markdown]
# We can see that the CNN model with Data Augmentation is the one with the highest accuracies (training and validation accuracies) and the smallest loss values.

# %% [markdown]
# # Encoder and Decoder
# Test with a Denoise encoder

# %% [markdown]
# ### First, extract the images to split into X and y. We also convert the images to gray scale (we remove convert them from RGB to Grayscale because the images are black and white so no need to use RGB)
#
#
# **Note: The for-loop has a counter to only extract the first 50 images. Due to Google-Colab is crashing to load all images due to insufficient RAM.**

# %%
train_generator_ia.reset()
X_train, y_train = next(train_generator_ia)
X_train = X_train.mean(axis=3)
X_train = np.expand_dims(X_train, axis = -1)
for i in range(1,50):
  X, y = next(train_generator_ia)
  X = X.mean(axis=3)
  X = np.expand_dims(X, axis = -1)
  X_train = np.append(X_train, X, axis = 0)

test_generator_ia.reset()
X_test, y_test = next(train_generator_ia)
X_test = X_test.mean(axis=3)
X_test = np.expand_dims(X_test, axis = -1)
for i in range(1,50):
  X, y = next(test_generator_ia)
  X = X.mean(axis=3)
  X = np.expand_dims(X, axis = -1)
  X_test = np.append(X_test, X, axis = 0)

# %%
class Denoise(tf.keras.Model):
  def __init__(self):
    super(Denoise, self).__init__()
    self.encoder = tf.keras.Sequential([
      tf.keras.layers.Input(shape=(300, 300, 1)),
      tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same', strides=2),
      tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      tf.keras.layers.Conv2DTranspose(8, kernel_size=3, strides=2, activation='relu', padding='same'),
      tf.keras.layers.Conv2DTranspose(16, kernel_size=3, strides=2, activation='relu', padding='same'),
      tf.keras.layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

# %%
autoencoder = Denoise()
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(X_train, X_train,
                epochs=20,
                shuffle=True,
                validation_data = (X_test, X_test))

# %%
decoded_imgs = autoencoder.predict(X_test)

n = 4
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(tf.squeeze(X_test[i]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(tf.squeeze(decoded_imgs[i]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# # Plot accuracies and losses

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize=(15,15))
axes[0,0].plot(history1.history['accuracy'], label = 'Base model')
axes[0,0].plot(history2.history['accuracy'], label = 'CNN model without DA')
axes[0,0].plot(history3.history['accuracy'], label = 'CNN model with DA')
axes[0,0].plot(history4.history['accuracy'], label = 'CNN model with DA and Norm.')
axes[0,0].plot(history5.history['accuracy'], label = 'LSTM model')
axes[0,0].plot(history.history['Output_accuracy'], label = 'GoogLeNet')
axes[0,0].set_xlabel('Epoch')
axes[0,0].set_ylabel('Accuracy')

axes[1,0].plot(history1.history['val_accuracy'], label = 'Base model')
axes[1,0].plot(history2.history['val_accuracy'], label = 'CNN model without DA')
axes[1,0].plot(history3.history['val_accuracy'], label = 'CNN model with DA')
axes[1,0].plot(history4.history['val_accuracy'], label = 'CNN model with DA and Norm.')
axes[1,0].plot(history5.history['val_accuracy'], label = 'LSTM model')
axes[0,0].plot(history.history['val_Output_accuracy'], label = 'GoogLeNet')
axes[1,0].set_xlabel('Epoch')
axes[1,0].set_ylabel('Val. Accuracy')

axes[0,1].plot(history1.history['loss'], label = 'Base model')
axes[0,1].plot(history2.history['loss'], label = 'CNN model without DA')
axes[0,1].plot(history3.history['loss'], label = 'CNN model with DA')
axes[0,1].plot(history4.history['loss'], label = 'CNN model with DA and Norm.')
axes[0,1].plot(history5.history['loss'], label = 'LSTM model')
axes[0,0].plot(history.history['Output_loss'], label = 'GoogLeNet')
axes[0,1].set_xlabel('Epoch')
axes[0,1].set_ylabel('Loss')

axes[1,1].plot(history1.history['val_loss'], label = 'Base model')
axes[1,1].plot(history2.history['val_loss'], label = 'CNN model without DA')
axes[1,1].plot(history3.history['val_loss'], label = 'CNN model with DA')
axes[1,1].plot(history4.history['val_loss'], label = 'CNN model with DA and Norm.')
axes[1,1].plot(history5.history['val_loss'], label = 'LSTM model')
axes[0,0].plot(history.history['val_Output_loss'], label = 'GoogLeNet')
axes[1,1].set_xlabel('Epoch')
axes[1,1].set_ylabel('Val. Loss')

plt.legend()
plt.show()

# %% [markdown]
# We can see that the CNN model with Data Augmentation is the one with the highest accuracies (training and validation accuracies) and the smallest loss values.
